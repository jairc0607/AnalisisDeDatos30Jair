# %% [markdown]
# # Primer entorno de python

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
#Comentario de una sola linea
"""
    Comentario de varias lineas
    Comentario de varias lineas
    Comentario de varias lineas
    Comentario de varias lineas
"""
# Out:
# 'Comentario de varias lineas\nComentario de varias lineas\nComentario de varias lineas\nComentario de varias lineas'
